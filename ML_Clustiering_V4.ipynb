# %% [markdown]
# # 라이브러리를 불러옵니다

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 핑크색 warning 안내문 방지 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 한글폰트 사용을 위한 세팅

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux(Colab)
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont
        
        font_family = "NanumBarunGothic"
    return font_family

plt.rc("font", family=get_font_family())
plt.rc("axes", unicode_minus=False)

# %% [markdown]
# # 데이터 셋 로드

# %%
import glob

# %%
path = glob.glob('*.csv')
path
# Out:
# ['pets_cleansed.csv']

# %%
df = pd.read_csv(path[0], encoding = 'utf-8')
df
# Out:
#            품종  나이  산책시간(시간)    체중 성별 중성화여부          색상     음수량  성별_라벨링  \
# 0     골든 리트리버  13       0.5  27.0  M     N          갈색  1755.0       1
# 1     골든 리트리버  10       0.5  25.0  F     N          갈색  1625.0       0
# 2     골든 리트리버   9       0.5  40.0  M     N          갈색  2600.0       1
# 3     골든 리트리버   8       0.5  28.0  F     N          갈색  1820.0       0
# 4     골든 리트리버   8       0.5  33.0  M     N          갈색  2145.0       1
# ...       ...  ..       ...   ... ..   ...         ...     ...     ...
# 5669    프렌치불독   1       0.8   4.0  M     N           흑   260.0       1
# 5670    프렌치불독   0       0.5   3.5  M     N          검정   227.5       1
# 5671    프렌치불독   0       0.5   5.2  M     N  백색, 갈색, 흑색   338.0       1
# 5672   화이트테리어  13       0.5   7.3  F     Y           흰   474.5       0
# 5673       휘펫   2       1.0  14.0  M     N         베이지   910.0       1
#
#       중성화_라벨링 크기  크기_라벨링
# 0           0  대       2
# 1           0  대       2
# 2           0  대       2
# 3           0  대       2
# 4           0  대       2
# ...       ... ..     ...
# 5669        0  소       0
# 5670        0  소       0
# 5671        0  소       0
# 5672        1  소       0
# 5673        0  중       1
#
# [5674 rows x 12 columns]

# %% [markdown]
# # 데이터 살펴보기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5674 entries, 0 to 5673
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   품종        5674 non-null   object
#  1   나이        5674 non-null   int64
#  2   산책시간(시간)  5674 non-null   float64
#  3   체중        5674 non-null   float64
#  4   성별        5674 non-null   object
#  5   중성화여부     5674 non-null   object
#  6   색상        5674 non-null   object
#  7   음수량       5674 non-null   float64
#  8   성별_라벨링    5674 non-null   int64
#  9   중성화_라벨링   5674 non-null   int64
#  10  크기        5674 non-null   object
#  11  크기_라벨링    5674 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 532.1+ KB

# %%
df.describe()
# Out:
#                 나이     산책시간(시간)           체중          음수량       성별_라벨링  \
# count  5674.000000  5674.000000  5674.000000  5674.000000  5674.000000
# mean      1.955939     0.892510     7.444949   483.921678     0.649806
# std       2.603371     0.163133     6.894764   448.159680     0.477073
# min       0.000000     0.500000     0.040000     2.600000     0.000000
# 25%       0.000000     0.800000     2.655000   172.575000     0.000000
# 50%       1.000000     0.800000     5.000000   325.000000     1.000000
# 75%       3.000000     1.000000    10.000000   650.000000     1.000000
# max      18.000000     1.500000    60.000000  3900.000000     1.000000
#
#            중성화_라벨링       크기_라벨링
# count  5674.000000  5674.000000
# mean      0.087769     0.346493
# std       0.282983     0.610848
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     1.000000
# max       1.000000     2.000000

# %%
#결측치 시각회
plt.figure(figsize = (8, 5))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # 각 컬럼 별 히스토그램 그려서 데이터 분포 보기
# df.hist(figsize = (12,8))
# plt.show()

# %% [markdown]
# # 범주형 변수 제외 - 전처리

# %%
df.columns
# Out:
# Index(['품종', '나이', '산책시간(시간)', '체중', '성별', '중성화여부', '색상', '음수량', '성별_라벨링',
#        '중성화_라벨링', '크기', '크기_라벨링'],
#       dtype='object')

# %%
#범주형 변수들은 제외하고 새로운 변수로 선언
C1 = df[['나이','산책시간(시간)', '체중', '성별_라벨링',
       '중성화_라벨링','크기_라벨링', '음수량']]

# %%
#잘 담겨있는지 확인
C1
# Out:
#       나이  산책시간(시간)    체중  성별_라벨링  중성화_라벨링  크기_라벨링     음수량
# 0     13       0.5  27.0       1        0       2  1755.0
# 1     10       0.5  25.0       0        0       2  1625.0
# 2      9       0.5  40.0       1        0       2  2600.0
# 3      8       0.5  28.0       0        0       2  1820.0
# 4      8       0.5  33.0       1        0       2  2145.0
# ...   ..       ...   ...     ...      ...     ...     ...
# 5669   1       0.8   4.0       1        0       0   260.0
# 5670   0       0.5   3.5       1        0       0   227.5
# 5671   0       0.5   5.2       1        0       0   338.0
# 5672  13       0.5   7.3       0        1       0   474.5
# 5673   2       1.0  14.0       1        0       1   910.0
#
# [5674 rows x 7 columns]

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## 상관분석

# %%
C1.corr()
# Out:
#                 나이  산책시간(시간)        체중    성별_라벨링   중성화_라벨링    크기_라벨링       음수량
# 나이        1.000000 -0.056727  0.283098  0.097001  0.366550  0.202140  0.283098
# 산책시간(시간) -0.056727  1.000000  0.537268  0.047376 -0.064798  0.477659  0.537268
# 체중        0.283098  0.537268  1.000000  0.127471  0.012856  0.916428  1.000000
# 성별_라벨링    0.097001  0.047376  0.127471  1.000000  0.183315  0.110984  0.127471
# 중성화_라벨링   0.366550 -0.064798  0.012856  0.183315  1.000000 -0.034216  0.012856
# 크기_라벨링    0.202140  0.477659  0.916428  0.110984 -0.034216  1.000000  0.916428
# 음수량       0.283098  0.537268  1.000000  0.127471  0.012856  0.916428  1.000000

# %%
plt.figure(figsize = (16,9))

sns.heatmap(data = C1.corr(),
           cmap = 'Blues', 
           annot = True, fmt = '0.4f')
# Out:
# <AxesSubplot:>

# %%
corr_bar = []

for column in C1.columns:
    print(f"{column}과 크기의 상관관계:{C1[column].corr(C1['크기_라벨링'])}")
    corr_bar.append(C1[column].corr(C1['크기_라벨링']))
# Out:
# 나이과 크기의 상관관계:0.2021404585500324
# 산책시간(시간)과 크기의 상관관계:0.47765942510271586
# 체중과 크기의 상관관계:0.9164284511703006
# 성별_라벨링과 크기의 상관관계:0.1109842052361599
# 중성화_라벨링과 크기의 상관관계:-0.03421605948347803
# 크기_라벨링과 크기의 상관관계:1.0
# 음수량과 크기의 상관관계:0.9164284511703032

# %%
plt.figure(figsize = (15,8))
sns.barplot(C1.columns, corr_bar)
plt.show()

# %% [markdown]
# # ElbowPoint

# %%
# 군집화 라이브러리 불러오기 .
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# %%
data = C1

# %%
x = [] #k가 몇개인지 -
y = [] #응집도가 몇인지 

# 범위가 1~30인 이유
for k in range (1,30): 
    kmeans = KMeans(n_clusters = k) # 1~ 29개의 군집화 된 객체를 kmeans라고 함   
    kmeans.fit(data)               # kmeans에다가 data2를 학습시킬것임 
    
    x.append(k)
    y.append(kmeans.inertia_)

    
#k가 n개 일 때 응집도는 a라고 이해하면 된다

# %%
# 그래프 그리기
plt.figure(figsize = (15,8))
plt.plot(x, y)
plt.show()

# %% [markdown]
# # 군집화(k=4) With T-SNE

# %%
# 3개로 군집화 된 객체를 생성 
kmeans = KMeans(n_clusters = 4)

# %%
# 군집화 할 데이터 'data2'를 학습시키기 
kmeans.fit(data)
# Out:
# KMeans(n_clusters=4)

# %%
# 학습된 kmeans의 응집도 확인 (각 데이터로부터 자신이 속한 군집의 중심까지의 거리)
# 응집도가 낮을수록 군집화가 더 잘되어있는 것이다

# %%
#각 군집 별 중앙 값 
print(kmeans.cluster_centers_[0])
print(kmeans.cluster_centers_[1])
print(kmeans.cluster_centers_[2])
print(kmeans.cluster_centers_[3])# 얘는 뒤에 e가 붙어서 "*10" 으로 계산해줘야 함
# Out:
# [3.4680000e+00 1.1540000e+00 2.7928760e+01 7.9200000e-01 8.8000000e-02
#  2.0000000e+00 1.8153694e+03]
# [2.68048229e+00 9.34740015e-01 8.59039940e+00 6.86510927e-01
#  1.34137151e-01 3.24039186e-01 5.58375961e+02]
# [2.78735632e+00 9.96206897e-01 1.66059770e+01 7.27586207e-01
#  5.74712644e-02 1.19080460e+00 1.07938851e+03]
# [ 1.31670282e+00  8.26929036e-01  2.91719554e+00  6.02726991e-01
#   7.68515649e-02 -2.10942375e-15  1.89617710e+02]

# %%
data
# Out:
#       나이  산책시간(시간)    체중  성별_라벨링  중성화_라벨링  크기_라벨링     음수량
# 0     13       0.5  27.0       1        0       2  1755.0
# 1     10       0.5  25.0       0        0       2  1625.0
# 2      9       0.5  40.0       1        0       2  2600.0
# 3      8       0.5  28.0       0        0       2  1820.0
# 4      8       0.5  33.0       1        0       2  2145.0
# ...   ..       ...   ...     ...      ...     ...     ...
# 5669   1       0.8   4.0       1        0       0   260.0
# 5670   0       0.5   3.5       1        0       0   227.5
# 5671   0       0.5   5.2       1        0       0   338.0
# 5672  13       0.5   7.3       0        1       0   474.5
# 5673   2       1.0  14.0       1        0       1   910.0
#
# [5674 rows x 7 columns]

# %%
data['labels'] = kmeans.predict(data)

# %%
data.head()
# Out:
#    나이  산책시간(시간)    체중  성별_라벨링  중성화_라벨링  크기_라벨링     음수량  labels
# 0  13       0.5  27.0       1        0       2  1755.0       0
# 1  10       0.5  25.0       0        0       2  1625.0       0
# 2   9       0.5  40.0       1        0       2  2600.0       0
# 3   8       0.5  28.0       0        0       2  1820.0       0
# 4   8       0.5  33.0       1        0       2  2145.0       0

# %%
data['labels'].value_counts()
# Out:
# 3    3227
# 1    1327
# 2     870
# 0     250
# Name: labels, dtype: int64

# %%
scaler = StandardScaler()
scaler_data = scaler.fit_transform(data)

# %%
tsne = TSNE()

# %%
data_tsne = pd.DataFrame(data = tsne.fit_transform(scaler_data), columns = ['tsne1', 'tsne2'])

# %%
data_tsne['labels'] = data['labels']

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(x = 'tsne1', y = 'tsne2', hue = 'labels', data = data_tsne)
plt.show()

# %%
data_tsne
# Out:
#           tsne1      tsne2  labels
# 0    -69.994064  -5.606724       0
# 1    -69.949547  -5.189760       0
# 2    -70.330338  -6.170374       0
# 3    -69.994934  -5.211133       0
# 4    -70.219887  -5.945851       0
# ...         ...        ...     ...
# 5669   4.942054   1.211682       3
# 5670 -13.576929  -5.117557       3
# 5671 -13.328907  -5.298109       3
# 5672 -32.316544 -72.701553       1
# 5673   7.654195 -41.626907       2
#
# [5674 rows x 3 columns]

# %% [markdown]
# # 결과해석 & 시각화
# ## (1) 앞에 빼놨던 컬럼 붙이기

# %%
data
# Out:
#       나이  산책시간(시간)    체중  성별_라벨링  중성화_라벨링  크기_라벨링     음수량  labels
# 0     13       0.5  27.0       1        0       2  1755.0       0
# 1     10       0.5  25.0       0        0       2  1625.0       0
# 2      9       0.5  40.0       1        0       2  2600.0       0
# 3      8       0.5  28.0       0        0       2  1820.0       0
# 4      8       0.5  33.0       1        0       2  2145.0       0
# ...   ..       ...   ...     ...      ...     ...     ...     ...
# 5669   1       0.8   4.0       1        0       0   260.0       3
# 5670   0       0.5   3.5       1        0       0   227.5       3
# 5671   0       0.5   5.2       1        0       0   338.0       3
# 5672  13       0.5   7.3       0        1       0   474.5       1
# 5673   2       1.0  14.0       1        0       1   910.0       2
#
# [5674 rows x 8 columns]

# %%
df
# Out:
#            품종  나이  산책시간(시간)    체중 성별 중성화여부          색상     음수량  성별_라벨링  \
# 0     골든 리트리버  13       0.5  27.0  M     N          갈색  1755.0       1
# 1     골든 리트리버  10       0.5  25.0  F     N          갈색  1625.0       0
# 2     골든 리트리버   9       0.5  40.0  M     N          갈색  2600.0       1
# 3     골든 리트리버   8       0.5  28.0  F     N          갈색  1820.0       0
# 4     골든 리트리버   8       0.5  33.0  M     N          갈색  2145.0       1
# ...       ...  ..       ...   ... ..   ...         ...     ...     ...
# 5669    프렌치불독   1       0.8   4.0  M     N           흑   260.0       1
# 5670    프렌치불독   0       0.5   3.5  M     N          검정   227.5       1
# 5671    프렌치불독   0       0.5   5.2  M     N  백색, 갈색, 흑색   338.0       1
# 5672   화이트테리어  13       0.5   7.3  F     Y           흰   474.5       0
# 5673       휘펫   2       1.0  14.0  M     N         베이지   910.0       1
#
#       중성화_라벨링 크기  크기_라벨링
# 0           0  대       2
# 1           0  대       2
# 2           0  대       2
# 3           0  대       2
# 4           0  대       2
# ...       ... ..     ...
# 5669        0  소       0
# 5670        0  소       0
# 5671        0  소       0
# 5672        1  소       0
# 5673        0  중       1
#
# [5674 rows x 12 columns]

# %%
df['labels'] = data['labels']

# %%
df.head()
# Out:
#         품종  나이  산책시간(시간)    체중 성별 중성화여부  색상     음수량  성별_라벨링  중성화_라벨링 크기  \
# 0  골든 리트리버  13       0.5  27.0  M     N  갈색  1755.0       1        0  대
# 1  골든 리트리버  10       0.5  25.0  F     N  갈색  1625.0       0        0  대
# 2  골든 리트리버   9       0.5  40.0  M     N  갈색  2600.0       1        0  대
# 3  골든 리트리버   8       0.5  28.0  F     N  갈색  1820.0       0        0  대
# 4  골든 리트리버   8       0.5  33.0  M     N  갈색  2145.0       1        0  대
#
#    크기_라벨링  labels
# 0       2       0
# 1       2       0
# 2       2       0
# 3       2       0
# 4       2       0

# %% [markdown]
# ## (2) 그룹별 갯수 시각화

# %%
(df['labels'].value_counts(normalize = True)*100).round(1)
# Out:
# 3    56.9
# 1    23.4
# 2    15.3
# 0     4.4
# Name: labels, dtype: float64

# %%
(df['labels'].value_counts(normalize = True)*100).round(1).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## (3) 그룹별 평균 크기 비교

# %%
# 시각화를 위해서 각 그룹별 size을 따로 변수로 생성
size0 = df[df['labels'] == 0]['크기_라벨링'].mean()
size1 = df[df['labels'] == 1]['크기_라벨링'].mean()
size2 = df[df['labels'] == 2]['크기_라벨링'].mean()
size3 = df[df['labels'] == 3]['크기_라벨링'].mean()

# %%
# 주의 모든 과정을 똑같이 하였어도 kmeans의 기본 중심값 설정은 랜덤임
plt.figure(figsize = (15,8))
sns.barplot(x = ['group_0', 'group_1', 'group_2', 'group_3'], y = [size0, size1, size2, size3] )
plt.show()

# %% [markdown]
# ## (4) 그룹별 평균 나이 비교

# %%
# 시각화를 위해서 각 그룹별 size을 따로 변수로 생성
age0 = df[df['labels'] == 0]['나이'].mean()
age1 = df[df['labels'] == 1]['나이'].mean()
age2 = df[df['labels'] == 2]['나이'].mean()
age3 = df[df['labels'] == 3]['나이'].mean()
# 주의 모든 과정을 똑같이 하였어도 kmeans의 기본 중심값 설정은 랜덤임
plt.figure(figsize = (15,8))
sns.barplot(x = ['group_0', 'group_1', 'group_2','group3'], y = [age0, age1, age2,age3] )
plt.show()

# %% [markdown]
# ## (5) 그룹별 평균 체중비교

# %%
# 시각화를 위해서 각 그룹별 size을 따로 변수로 생성
wgt0 = df[df['labels'] == 0]['체중'].mean()
wgt1 = df[df['labels'] == 1]['체중'].mean()
wgt2 = df[df['labels'] == 2]['체중'].mean()
wgt3 = df[df['labels'] == 3]['체중'].mean()
# 주의 모든 과정을 똑같이 하였어도 kmeans의 기본 중심값 설정은 랜덤임
plt.figure(figsize = (15,8))
sns.barplot(x = ['group_0', 'group_1', 'group_2','group_3'], y = [wgt0, wgt1, wgt2, wgt3] )
plt.show()

# %% [markdown]
# ## (6) 그룹별 평균 권장 산책시간 비교

# %%
# 시각화를 위해서 각 그룹별 size을 따로 변수로 생성
recom0 = df[df['labels'] == 0]['산책시간(시간)'].mean()
recom1 = df[df['labels'] == 1]['산책시간(시간)'].mean()
recom2 = df[df['labels'] == 2]['산책시간(시간)'].mean()
recom3 = df[df['labels'] == 3]['산책시간(시간)'].mean()
# 주의 모든 과정을 똑같이 하였어도 kmeans의 기본 중심값 설정은 랜덤임
plt.figure(figsize = (15,8))
sns.barplot(x = ['group_0', 'group_1', 'group_2','group_3'], y = [recom0, recom1, recom2,recom3] )
plt.show()

# %% [markdown]
# ## (7)그룹별 특징
# - 나이를 기준으로 비교

# %%
df.head()
# Out:
#         품종  나이  산책시간(시간)    체중 성별 중성화여부  색상     음수량  성별_라벨링  중성화_라벨링 크기  \
# 0  골든 리트리버  13       0.5  27.0  M     N  갈색  1755.0       1        0  대
# 1  골든 리트리버  10       0.5  25.0  F     N  갈색  1625.0       0        0  대
# 2  골든 리트리버   9       0.5  40.0  M     N  갈색  2600.0       1        0  대
# 3  골든 리트리버   8       0.5  28.0  F     N  갈색  1820.0       0        0  대
# 4  골든 리트리버   8       0.5  33.0  M     N  갈색  2145.0       1        0  대
#
#    크기_라벨링  labels
# 0       2       0
# 1       2       0
# 2       2       0
# 3       2       0
# 4       2       0

# %%
group = df[(df['labels']==0) | (df['labels']==1) | (df['labels']==2) | (df['labels']==3) ]

# %%
group['labels'].value_counts()
# Out:
# 3    3227
# 1    1327
# 2     870
# 0     250
# Name: labels, dtype: int64

# %%
group = group.groupby('labels').mean().reset_index()
group
# Out:
#    labels        나이  산책시간(시간)         체중          음수량    성별_라벨링   중성화_라벨링  \
# 0       0  3.468000  1.154000  27.928760  1815.369400  0.792000  0.088000
# 1       1  2.680482  0.934740   8.590399   558.375961  0.686511  0.134137
# 2       2  2.787356  0.996207  16.605977  1079.388506  0.727586  0.057471
# 3       3  1.316703  0.826929   2.917196   189.617710  0.602727  0.076852
#
#      크기_라벨링
# 0  2.000000
# 1  0.324039
# 2  1.190805
# 3  0.000000

# %%
column = group.columns
column
# Out:
# Index(['labels', '나이', '산책시간(시간)', '체중', '음수량', '성별_라벨링', '중성화_라벨링', '크기_라벨링'], dtype='object')

# %%
# 반복문으로 그림그리기
f, ax = plt.subplots(3,3,figsize=(20,13))

for i in range(1,8):
        sns.barplot(x='labels', y=column[i], data=group, ax = ax[i//3, i%3])

# sns.barplot(x='labels', y='크기', data = group, ax = ax[0,0])
# sns.barplot(x='labels', y='나이', data = group, ax = ax[0,1])
# sns.barplot(x='labels', y='체중', data = group, ax = ax[1,0])

plt.show()

# %%
df[df['labels']==0].describe()
# Out:
#                나이    산책시간(시간)          체중         음수량      성별_라벨링     중성화_라벨링  \
# count  250.000000  250.000000  250.000000   250.00000  250.000000  250.000000
# mean     3.468000    1.154000   27.928760  1815.36940    0.792000    0.088000
# std      1.856546    0.283559    5.316471   345.57061    0.406691    0.283863
# min      0.000000    0.500000   22.300000  1449.50000    0.000000    0.000000
# 25%      2.000000    1.000000   25.000000  1625.00000    1.000000    0.000000
# 50%      3.000000    1.000000   26.900000  1748.50000    1.000000    0.000000
# 75%      5.000000    1.500000   30.000000  1950.00000    1.000000    0.000000
# max     13.000000    1.500000   60.000000  3900.00000    1.000000    1.000000
#
#        크기_라벨링  labels
# count   250.0   250.0
# mean      2.0     0.0
# std       0.0     0.0
# min       2.0     0.0
# 25%       2.0     0.0
# 50%       2.0     0.0
# 75%       2.0     0.0
# max       2.0     0.0

# %%
df[df['labels']==1].describe()
# Out:
#                 나이    산책시간(시간)           체중          음수량       성별_라벨링  \
# count  1327.000000  1327.00000  1327.000000  1327.000000  1327.000000
# mean      2.680482     0.93474     8.590399   558.375961     0.686511
# std       2.552100     0.14755     1.954638   127.051480     0.464086
# min       0.000000     0.50000     5.800000   377.000000     0.000000
# 25%       1.000000     0.80000     7.000000   455.000000     0.000000
# 50%       2.000000     1.00000     8.100000   526.500000     1.000000
# 75%       4.000000     1.00000    10.000000   650.000000     1.000000
# max      16.000000     1.50000    12.500000   812.500000     1.000000
#
#            중성화_라벨링       크기_라벨링  labels
# count  1327.000000  1327.000000  1327.0
# mean      0.134137     0.324039     1.0
# std       0.340928     0.468191     0.0
# min       0.000000     0.000000     1.0
# 25%       0.000000     0.000000     1.0
# 50%       0.000000     0.000000     1.0
# 75%       0.000000     1.000000     1.0
# max       1.000000     1.000000     1.0

# %%
df[df['labels']==2].describe()
# Out:
#                나이    산책시간(시간)          체중          음수량      성별_라벨링  \
# count  870.000000  870.000000  870.000000   870.000000  870.000000
# mean     2.787356    0.996207   16.605977  1079.388506    0.727586
# std      1.786557    0.116516    2.538083   164.975371    0.445458
# min      0.000000    0.500000   12.610000   819.650000    0.000000
# 25%      2.000000    1.000000   15.000000   975.000000    0.000000
# 50%      2.500000    1.000000   16.000000  1040.000000    1.000000
# 75%      3.750000    1.000000   18.650000  1212.250000    1.000000
# max     14.000000    1.500000   22.100000  1436.500000    1.000000
#
#           중성화_라벨링      크기_라벨링  labels
# count  870.000000  870.000000   870.0
# mean     0.057471    1.190805     2.0
# std      0.232875    0.393161     0.0
# min      0.000000    1.000000     2.0
# 25%      0.000000    1.000000     2.0
# 50%      0.000000    1.000000     2.0
# 75%      0.000000    1.000000     2.0
# max      1.000000    2.000000     2.0

# %%
df[df['labels']==3].describe()
# Out:
#                 나이     산책시간(시간)           체중          음수량       성별_라벨링  \
# count  3227.000000  3227.000000  3227.000000  3227.000000  3227.000000
# mean      1.316703     0.826929     2.917196   189.617710     0.602727
# std       2.669681     0.121458     1.383240    89.910576     0.489409
# min       0.000000     0.500000     0.040000     2.600000     0.000000
# 25%       0.000000     0.800000     2.000000   130.000000     0.000000
# 50%       0.000000     0.800000     3.000000   195.000000     1.000000
# 75%       1.000000     0.800000     4.000000   260.000000     1.000000
# max      18.000000     1.500000     5.750000   373.750000     1.000000
#
#            중성화_라벨링  크기_라벨링  labels
# count  3227.000000  3227.0  3227.0
# mean      0.076852     0.0     3.0
# std       0.266397     0.0     0.0
# min       0.000000     0.0     3.0
# 25%       0.000000     0.0     3.0
# 50%       0.000000     0.0     3.0
# 75%       0.000000     0.0     3.0
# max       1.000000     0.0     3.0

# %%
df.head()
# Out:
#         품종  나이  산책시간(시간)    체중 성별 중성화여부  색상     음수량  성별_라벨링  중성화_라벨링 크기  \
# 0  골든 리트리버  13       0.5  27.0  M     N  갈색  1755.0       1        0  대
# 1  골든 리트리버  10       0.5  25.0  F     N  갈색  1625.0       0        0  대
# 2  골든 리트리버   9       0.5  40.0  M     N  갈색  2600.0       1        0  대
# 3  골든 리트리버   8       0.5  28.0  F     N  갈색  1820.0       0        0  대
# 4  골든 리트리버   8       0.5  33.0  M     N  갈색  2145.0       1        0  대
#
#    크기_라벨링  labels
# 0       2       0
# 1       2       0
# 2       2       0
# 3       2       0
# 4       2       0

# %%
df[df['labels']==0].std().plot()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 나이     산책시간(시간)           체중          음수량       성별_라벨링  \
# count  5674.000000  5674.000000  5674.000000  5674.000000  5674.000000
# mean      1.955939     0.892510     7.444949   483.921678     0.649806
# std       2.603371     0.163133     6.894764   448.159680     0.477073
# min       0.000000     0.500000     0.040000     2.600000     0.000000
# 25%       0.000000     0.800000     2.655000   172.575000     0.000000
# 50%       1.000000     0.800000     5.000000   325.000000     1.000000
# 75%       3.000000     1.000000    10.000000   650.000000     1.000000
# max      18.000000     1.500000    60.000000  3900.000000     1.000000
#
#            중성화_라벨링       크기_라벨링       labels
# count  5674.000000  5674.000000  5674.000000
# mean      0.087769     0.346493     2.246740
# std       0.282983     0.610848     0.958192
# min       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     1.000000
# 50%       0.000000     0.000000     3.000000
# 75%       0.000000     1.000000     3.000000
# max       1.000000     2.000000     3.000000

# %%
plt.figure(figsize=(12,8))
df[df['labels']==0]['체중'].hist()
plt.show()

# %%
plt.figure(figsize=(12,8))
df[df['labels']==1]['체중'].hist()
plt.show()

# %%
plt.figure(figsize=(12,8))
df[df['labels']==2]['체중'].hist()
plt.show()

# %%
plt.figure(figsize=(12,8))
df[df['labels']==3]['체중'].hist()
plt.show()
