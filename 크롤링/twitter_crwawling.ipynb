# %%
# 핑크색 warning 안내문 방지 
import warnings
warnings.filterwarnings('ignore')

# %%
# 워드크라우드에 사용할 라이브러리를 불러옵니다
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # 파이썬 라이브러리 설치
# 출처 : https://soyoung-new-challenge.tistory.com/67
# https://blog.naver.com/syc5002/222678102386https://blog.naver.com/syc5002/222678102386

# %%
# !pip install snscrape
# Out:
# ...
# WARNING: Ignoring invalid distribution -quests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogletrans (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -quests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogletrans (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -quests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oogletrans (c:\programdata\anaconda3\lib\site-packages)
# ...

# %% [markdown]
# # 트위터 크롤링 2022년

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchScraper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('펫프렌들리 since:2022-01-01 until:2022-06-20').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df_1 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df_1
# Out:
#                     Datetime  \
# 0  2022-06-14 23:39:08+00:00
# 1  2022-06-13 06:30:42+00:00
# 2  2022-06-08 10:43:53+00:00
# 3  2022-06-08 10:43:53+00:00
# 4  2022-06-08 10:43:52+00:00
# ..                       ...
# 58 2022-01-22 16:55:58+00:00
# 59 2022-01-21 09:09:21+00:00
# 60 2022-01-12 14:03:36+00:00
# 61 2022-01-12 03:13:10+00:00
# 62 2022-01-08 15:26:05+00:00
#
#                                                  Text  Like
# 0   소금빵도 생긴것도 귀엽고 바삭하니 무난하게 먹을만 했구.. 꼭 에소만 있는게 아니라...     1
# 1   재패니즈 프렌치? 디저트 카페\n\n📍 연희동 애니브\n  \n롤케이크 카스테라 등...     8
# 2     여행가려 계획하다 어이없어서 써봄.  #펫언프렌들리 #애견동반 #펫프렌들리 #동물혐오     0
# 3   숙박객들이 비선호하는 룸으로 애초에 지정해두기 마련이며 동물은 주인이 외출하면 룸안...     0
# 4   펫프렌들리의 의미는 나의 공간에 동물들을 환영한다는것이다. 보통은 안전 보증금과 추...     0
# ..                                                ...   ...
# 58  마저 예약한 호텔 펫프렌들리라 강쥐 데려가도 되거든 저에게는반려강아지가한마리있 ht...     2
# 59  밖에서 만나는 분들 강쥐한테 무관심이거나, 좋아하는 분들은 강아지한테 아래로 손인사...     1
# 60  펫프렌들리 매장이래서\n조금 끌리는 중...\n좀 .. 멀지만 ... 이정도 거리면...     0
# ...

# %% [markdown]
# # 트위터 크롤링 2021년

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchScraper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('펫프렌들리 since:2021-01-01 until:2021-12-31').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df_2 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df_2
# Out:
#                     Datetime  \
# 0  2021-12-25 09:04:25+00:00
# 1  2021-12-22 09:42:44+00:00
# 2  2021-12-21 13:21:47+00:00
# 3  2021-12-17 05:20:47+00:00
# 4  2021-12-11 10:07:42+00:00
# ..                       ...
# 57 2021-04-04 13:43:39+00:00
# 58 2021-03-29 10:44:13+00:00
# 59 2021-03-14 22:08:06+00:00
# 60 2021-01-26 13:00:34+00:00
# 61 2021-01-15 15:05:36+00:00
#
#                                                  Text  Like
# 0                                   펫프렌들리 매장 너무 좋다...     0
# 1   허어어어억 카페에 고양이 들어왔어 고양이 고양이!!! 길냥이인가??? 펫프렌들리 매...     4
# 2   #야호펫 #반려동물 양산시, '펫프렌들리' 반려동물지원센터 설계공모 당선작 공개 h...     0
# 3   눈 내리는 제주, 오늘자 오공입니다.\n\n오늘은 마따따비 스틱을 줘봤는데 좋아하네...     0
# 4   동물권 이야기 가득한 전시회를 열어보는 게 목표인🧐..준비하면서 의견 나누고 공부하...    15
# ..                                                ...   ...
# 57  셔뇨 카페 하는데 고양이 전용 출입구 만들어놓을 정도로 펫프렌들리 카페라서 동네 길...    12
# 58  사람 둘 강아지 둘 산책하는데 횟집 호객하시는 분들이 다 "네 분 자리 있어요~" ...     8
# 59  바로 옆에 정말 산책하기 좋은 공원이 있고 걸어서 갈 수 있는 거리에 우리가 좋아하...     2
# ...

# %% [markdown]
# # 트위터 크롤링 '펫프렌들리' 2020년 01월 ~ 2022년 06월

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchScraper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('펫프렌들리 since:2020-01-01 until:2022-06-20').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df_3 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df_3
# Out:
#                      Datetime  \
# 0   2022-06-14 23:39:08+00:00
# 1   2022-06-13 06:30:42+00:00
# 2   2022-06-08 10:43:53+00:00
# 3   2022-06-08 10:43:53+00:00
# 4   2022-06-08 10:43:52+00:00
# ..                        ...
# 134 2020-06-16 05:03:33+00:00
# 135 2020-05-04 08:24:00+00:00
# 136 2020-03-13 08:03:48+00:00
# 137 2020-03-12 09:44:08+00:00
# 138 2020-02-06 06:30:31+00:00
#
#                                                   Text  Like
# 0    소금빵도 생긴것도 귀엽고 바삭하니 무난하게 먹을만 했구.. 꼭 에소만 있는게 아니라...     1
# 1    재패니즈 프렌치? 디저트 카페\n\n📍 연희동 애니브\n  \n롤케이크 카스테라 등...     8
# 2      여행가려 계획하다 어이없어서 써봄.  #펫언프렌들리 #애견동반 #펫프렌들리 #동물혐오     0
# 3    숙박객들이 비선호하는 룸으로 애초에 지정해두기 마련이며 동물은 주인이 외출하면 룸안...     0
# 4    펫프렌들리의 의미는 나의 공간에 동물들을 환영한다는것이다. 보통은 안전 보증금과 추...     0
# ..                                                 ...   ...
# 134  @g_y_e_o_l 펫프렌들리 아파트는 대부분 럭셔리 아파트들이라.. 강제로 호화로...     0
# 135  애견운동장, 애견카페, 펫프렌들리 등을 표방하는 영업장이라면서 ‘10킬로 이상 대형...    99
# ...

# %% [markdown]
# # 트위터 크롤링 '애견동반' 2020년 01월 ~ 2020년 12월

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchScraper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('애견동반 since:2020-01-01 until:2020-12-31').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df_4 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df_4
# Out:
#                      Datetime  \
# 0   2020-12-30 14:52:51+00:00
# 1   2020-12-29 21:15:26+00:00
# 2   2020-12-28 06:33:44+00:00
# 3   2020-12-27 03:31:50+00:00
# 4   2020-12-26 18:56:08+00:00
# ..                        ...
# 868 2020-01-02 16:52:29+00:00
# 869 2020-01-02 16:27:52+00:00
# 870 2020-01-02 15:59:11+00:00
# 871 2020-01-02 10:17:16+00:00
# 872 2020-01-01 09:18:46+00:00
#
#                                                   Text  Like
# 0    대치동맛집\n블랙푸들\n강아지\n귀요미\n멍\n건강검진\n선팔하면맞팔\n포메라이언\...     0
# 1                                    동네에 애견동반가능카페이따..!     1
# 2    간판에 애견동반 식당이라고 적혀있어서 우리 댕댕이가 여기 갔나보네ㅎㅎㅎ https:...     9
# 3    평창에서 우리 보리를 데려온지 오늘로 365일.\n꼭 다시 가보고 싶었습니다.\n\...    43
# 4                                   실낙원 애견 동반도 되나.. 멈멈     1
# ..                                                 ...   ...
# 868  암튼 그러고 우리 시간이 너무 이른 시간이라 와인 까러 출발~! 애견 동반 카페라서...     2
# 869  아니면 제주도 게하 중에서 애견동반 가능한 게하 잌ㅅ는데 거기 가서 강아지 힐링 하기 ㅎ     0
# ...

# %% [markdown]
# # 트위터 크롤링 '애견동반' 2021년 01월 ~ 2021년 12월

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchScraper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('애견동반 since:2021-01-01 until:2021-12-31').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df_5 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df_5
# Out:
#                       Datetime  \
# 0    2021-12-30 17:23:11+00:00
# 1    2021-12-30 12:50:43+00:00
# 2    2021-12-30 09:16:31+00:00
# 3    2021-12-30 08:47:02+00:00
# 4    2021-12-30 04:07:57+00:00
# ...                        ...
# 1134 2021-01-09 09:26:18+00:00
# 1135 2021-01-09 08:48:00+00:00
# 1136 2021-01-04 11:35:09+00:00
# 1137 2021-01-03 08:45:42+00:00
# 1138 2021-01-02 11:19:57+00:00
#
#                                                    Text  Like
# 0     #강다니엘_염염긋\n망원 도피\n당근라페샌드위치존맛ㅜㅜ 당근맛이많이안나고식감도물컹하...     3
# 1                      이모들 바우라움 갈만한가요 아직도 애견동반 갈만한데 못찾음     0
# 2     멸실 스텐철망 철심끈 레깅스양말 수기치료 뇌교육센터 일본퀼트 보충중 호매실꽃집 국궁...     0
# 3         애견동반글램핑 누적판매량 상위10 추천 https://t.co/iqJId0b5qC     0
# 4         애견동반글램핑 누적판매량 상위10 추천 https://t.co/PxFAFuuzhH     0
# ...                                                 ...   ...
# 1134                      애견동반팬션가서 댕댕이 구경이나 실컷하고싶다 ㅇ(-(     0
# 1135                    애견동반 가능 https://t.co/MM9jlZDovf     0
# ...

# %% [markdown]
# # 트위터 크롤링 '애견동반' 2022년 01월 ~ 2022년 06월

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchScraper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('애견동반 since:2022-01-01 until:2022-06-20').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df_6 = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df_6
# Out:
#                       Datetime  \
# 0    2022-06-19 23:03:31+00:00
# 1    2022-06-19 21:38:37+00:00
# 2    2022-06-19 20:09:25+00:00
# 3    2022-06-19 19:14:37+00:00
# 4    2022-06-19 17:11:26+00:00
# ...                        ...
# 1149 2022-01-02 02:33:15+00:00
# 1150 2022-01-01 15:52:40+00:00
# 1151 2022-01-01 08:53:10+00:00
# 1152 2022-01-01 08:41:11+00:00
# 1153 2022-01-01 07:12:41+00:00
#
#                                                    Text  Like
# 0     BMQ2IYZ8KT4R7VU\n\n영월여행의\n증량\n재료쇼핑몰\n칼라거펠트\n강남...     0
# 1     수원에 푸딩맛집 탐라에 흘러들어와서 오!하고 가보려 했더니만..ㅎㅎ\n애견동반은 가...     1
# 2     I37L0HJNRADC\n\n현장목수\n책글귀\n을지로회식\n피화기마을\n동원\n제...     0
# 3     IPWYFD8K0R3S\n\n그림같은사진\n시베리안허스키\n슬픈\n4기\n애견동반가...     0
# 4     6LQERSCDVBTWH\n\n스톤아트\n두뇌로\n한국관광공사\n셀프재료\n서면젤\...     0
# ...                                                 ...   ...
# 1149  #박지훈 #헬로메이 \n&lt;2022년 박지훈의 계획&gt;\n\n- 맥스랑 해보...    22
# 1150  오늘 카페상주견 있는 애견동반카페 갔는데,, 김탄 개웃김 자기 크기 2배 정도 되는...     2
# ...

# %% [markdown]
# # 크롤링 한 것들을 csv파일로 저장하기

# %%
tweets_2020 = tweets_df_4['Text'].tolist()
tweets_2021 = tweets_df_5['Text'].tolist()
tweets_2022 = tweets_df_6['Text'].tolist()

# %%
import pandas as pd

# %%
tweets_2020 = pd.DataFrame(tweets_2020)
tweets_2021 = pd.DataFrame(tweets_2021)
tweets_2022 = pd.DataFrame(tweets_2022)

# %%
tweets_2020.to_csv('tweets_2020.csv', index = False, encoding = 'utf-8')
tweets_2021.to_csv('tweets_2021.csv', index = False, encoding = 'utf-8')
tweets_2022.to_csv('tweets_2022.csv', index = False, encoding = 'utf-8')

# %%
pd.read_csv('tweets_2022.csv', encoding = 'utf-8')
# Out:
#                                                       0
# 0     BMQ2IYZ8KT4R7VU\n\n영월여행의\n증량\n재료쇼핑몰\n칼라거펠트\n강남...
# 1     수원에 푸딩맛집 탐라에 흘러들어와서 오!하고 가보려 했더니만..ㅎㅎ\n애견동반은 가...
# 2     I37L0HJNRADC\n\n현장목수\n책글귀\n을지로회식\n피화기마을\n동원\n제...
# 3     IPWYFD8K0R3S\n\n그림같은사진\n시베리안허스키\n슬픈\n4기\n애견동반가...
# 4     6LQERSCDVBTWH\n\n스톤아트\n두뇌로\n한국관광공사\n셀프재료\n서면젤\...
# ...                                                 ...
# 1149  #박지훈 #헬로메이 \n&lt;2022년 박지훈의 계획&gt;\n\n- 맥스랑 해보...
# 1150  오늘 카페상주견 있는 애견동반카페 갔는데,, 김탄 개웃김 자기 크기 2배 정도 되는...
# 1151  여자친구도 30대가 되었다\n축하해~☺️🙏 30대 레즈비언으로 진입한걸 환영해~~☺...
# 1152  오늘간 애견(동반)카페는 지금까지 같던\n동반카페들보다 제약이 있었는데\n그중 제일...
# 1153  우리 동생 일하는...카페에 가족 다 같이 놀러가기로 했어요...애견동반카페라 강아...
#
# [1154 rows x 1 columns]

# %% [markdown]
# # wordcloud 세팅

# %%
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor

# %%
# 말뭉치(corpus)는 자연어 분석 작업을 위해 만든 샘플 문서 집합을 말한다.
corpus = DoublespaceLineCorpus('tweets_2022.csv')
len(corpus)
# Out:
# 3455

# %%
word_extractor = WordExtractor()
word_extractor.train(corpus)
# Out:
# training was done. used memory 0.138 Gb

# %%
corpus = DoublespaceLineCorpus('tweets_2022.csv', iter_sent = True)
len(corpus)
# Out:
# 3138

# %%
# 잘 변환 되었는지 4개만 돌려보기 -> 문장을 토큰화 해보자 
i = 0
for d in corpus:
    print(i,d)
    i +=1
    if i > 4 :
        break
# Out:
# 0 0
# 1 "BMQ2IYZ8KT4R7VU
# 2 영월여행의
# 3 증량
# 4 재료쇼핑몰

# %% [markdown]
# ## RegexTokenizer 사용하기
# https://github.com/lovit/soynlp
# -  soynlp 는 세 가지 토크나이저를 제공
# - LTokenizer : L parts 에는 명사/동사/형용사/부사가 위치할 수 있습니다. 어절에서 L 만 잘 인식한다면 나머지 부분이 R parts 가 됩니다. LTokenizer 에는 L parts 의 단어 점수를 입력합니다.
#
# - MaxScoreTokenizer : 띄어쓰기가 제대로 지켜지지 않은 데이터라면, 문장의 띄어쓰기 기준으로 나뉘어진 단위가 L + [R] 구조라 가정할 수 없습니다. 하지만 사람은 띄어쓰기가 지켜지지 않은 문장에서 익숙한 단어부터 눈에 들어옵니다. 이 과정을 모델로 옮긴 MaxScoreTokenizer 역시 단어 점수를 이용합니다.
#
# - RegexTokenizer : 규칙 기반으로도 단어열을 만들 수 있습니다. 언어가 바뀌는 부분에서 우리는 단어의 경계를 인식합니다. 예를 들어 "아이고ㅋㅋㅜㅜ진짜?" 는 [아이고, ㅋㅋ, ㅜㅜ, 진짜, ?]로 쉽게 단어열을 나눕니다.

# %%
df = pd.read_csv("tweets_2022.csv", encoding="utf-8")

# %%
p1 = r'.*(애견동반 | 아직 | 제약 | 안 | 있다 ).*'
pro1 = df[df['0'].str.match(p1)]
pro1.shape
# Out:
# (340, 1)

# %%
pro1.head()
# Out:
#                                                     0
# 5   #생활문화 가족 여행 숙소로 제격인 고성 오션투유리조트 feat.애견동반 가능 ht...
# 7   하 애견카페 갔다가 애견동반 고깃집 갔는데 너무 귀엽죠오…🥹 https://t.co...
# 17  ㄱr끔 울애기 보고시퍼 하시는 님들이 계셔서 올렷따 지울 내때낑 보여드림 :) 울애...
# 18  수원 근처 가시면 다른 웨이팅 길어지는 가게 가시지마시고 온새미로 가보셔요들 뷰도 ...
# 19  저희 집 멍멍님이  한건 햇습니다😎(애견동반 가능한 음식점임 https://t.co...

# %%
sample_index = 10

# %%
sample_content = df['0'][sample_index]
sample_content
# Out:
# '@_with_dog 앗 즈이 직원네 집이 포항월포근처에서 애견동반펜션을 합니다!!\n그 집도 어린아이 둘이라 칠드런 대환영이요!!'

# %%
from soynlp.tokenizer import RegexTokenizer
tokenizer = RegexTokenizer()
tokenizer

# %%
tokened_content = tokenizer.tokenize(sample_content)
sample_content[:]
# Out:
# '@_with_dog 앗 즈이 직원네 집이 포항월포근처에서 애견동반펜션을 합니다!!\n그 집도 어린아이 둘이라 칠드런 대환영이요!!'

# %%
#  파이썬 개행문자 제거 
##(출처: 오늘코드 | https://www.youtube.com/watch?v=bAJW02Cmw1o)
def preprocess(text):
         text = re.sub('\\\\n', ' ', text)
         return text

# %%
sentences01 = df['0'].apply(preprocess)

# %% [markdown]
# # 워드클라우드 생성

# %%
#선명한 display를 위해 retina 옵션 추가 
# %config InlineBackend.figure_format = 'retina'

# %%
# 워드클라우드에 필요한 라이브러리를 불러옵니다 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
# 워드클라우드 라이브러리를 불러옵니다 
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %%
# 워드클라우드 폰트 지정 
#  https://www.inflearn.com/questions/31934
fontpath = 'C:/Users/LG/AppData/Local/Microsoft/Windows/Fonts/AppleSDGothicNeoM.ttf'

# %%
import matplotlib.pyplot as plt    
# %matplotlib inline

# %%
stopwords_kr = ['하지만', '그리고', '그런데', '나는', '저는', '제가', '내가',
 '그럼', '매우', '!!!', '!', '!!', '!!!!', '내', '정말', '너무',
 '많이', '많은', '것을', '이런', '저런', '합니다', '제품', '제품을'
 ,'사장이', '제품은', '개의', '다른', '지금까지', '않았습니다', '이', '두',
 '않습니다']

# %%
def displayWordCloud(data = None,
                     backgroundcolor = 'white', 
                     width = 1200,
                     height = 900):
    wordcloud = WordCloud(
    font_path = fontpath,
    stopwords = stopwords_kr,
    background_color = backgroundcolor,
    width = width, height = height).generate(data)
    plt.figure(figsize = (20, 15))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
p1 = r'.*(애견동반 | 아직 | 제약 | 안 | 어디 ).*'
collect01 = df[df['0'].str.match(p1)]
collect01.shape
# Out:
# (339, 1)

# %%
# %time
col01 = collect01['0'].apply(preprocess)
# %time
displayWordCloud(' '.join(col01))
# Out:
# Wall time: 0 ns
# Wall time: 0 ns
